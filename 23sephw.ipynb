# %%
n="akanksha sherkar"
print(n)
print(len(n))
# Out:
# akanksha sherkar
# 16

# %%
print(n[0:8:1])
# Out:
# akanksha

# %%
print(n[-16:-8:1])
# Out:
# akanksha

# %%
print(n[-9:-17:-1])
# Out:
# ahsknaka

# %%
print(n[9:16:1])
# Out:
# sherkar

# %%
print(n[-1:-8:-1])
# Out:
# rakrehs

# %%
print(n[-7:-1+1:-1])
# Out:
# s ahsknak

# %%
a="akanksha sherkar"
print(a[15:-8:-1])
# Out:
# rakrehs

# %%
print(a[15:8:-1])
# Out:
# rakrehs

# %%
print(a[-1:-8:-1])
# Out:
# rakrehs

# %%
print(a[-7::+1])
# Out:
# sherkar

# %%
print(a[-7:16:1])
# Out:
# sherkar

# %%
print(a[9::1])
# Out:
# sherkar

# %%
print(a[::1])
# Out:
# akanksha sherkar

# %%
print(a[-16::1])
# Out:
# akanksha sherkar

# %%
print(a[0:16:1])
# Out:
# akanksha sherkar

# %%
print(a[-16:16:1])
# Out:
# akanksha sherkar

# %%
print(a[-1:-17:-1])
# Out:
# rakrehs ahsknaka

# %%
print(a[15::-1])
# Out:
# rakrehs ahsknaka

# %%
print(a[15:0:-1])
# Out:
# rakrehs ahsknak

# %%
print(a[-1::-1])
# Out:
# rakrehs ahsknaka

# %%
print(a[15:-17:-1])
# Out:
# rakrehs ahsknaka

# %%
print(a[::2])
# Out:
# aakh hra

# %%
print(a[-16::2])
# Out:
# aakh hra

# %%
print(a[0:16:2])
# Out:
# aakh hra

# %%
print(a[-16:16:2])
# Out:
# aakh hra

# %%
print(a[-9:-6:1])
# Out:
# a s

# %%
print(a[7:10:1])
# Out:
# a s

# %%
print(a[7:-6:1])
# Out:
# a s

# %%
print(a[-9:10:1])
# Out:
# a s

# %%
print(a[9:6:-1])
# Out:
# s a

# %%
print(a[-7:-10:-1])
# Out:
# s a
